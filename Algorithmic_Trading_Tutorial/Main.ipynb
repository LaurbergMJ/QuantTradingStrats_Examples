# %%
import yfinance as yf 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end="2021-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2009-12-31    7.611786    7.619643    7.520000    7.526071    6.415357
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.515213
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.526475
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.422665
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.410790
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.404572
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  135.068588
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.270172
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  132.133850
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  131.116028
#
#                Volume
# Date
# 2009-12-31  352410800
# 2010-01-04  493729600
# 2010-01-05  601904800
# ...

# %%
ticker = ['SPY', 'AAPL', 'KO']
stocks = yf.download(ticker, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2770 entries, 2009-12-31 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2770 non-null   float64
#  1   (Adj Close, KO)    2770 non-null   float64
#  2   (Adj Close, SPY)   2770 non-null   float64
#  3   (Close, AAPL)      2770 non-null   float64
#  4   (Close, KO)        2770 non-null   float64
#  5   (Close, SPY)       2770 non-null   float64
#  6   (High, AAPL)       2770 non-null   float64
#  7   (High, KO)         2770 non-null   float64
#  8   (High, SPY)        2770 non-null   float64
#  9   (Low, AAPL)        2770 non-null   float64
#  10  (Low, KO)          2770 non-null   float64
#  11  (Low, SPY)         2770 non-null   float64
#  12  (Open, AAPL)       2770 non-null   float64
#  13  (Open, KO)         2770 non-null   float64
#  14  (Open, SPY)        2770 non-null   float64
# ...

# %%
stocks.to_csv("stocksYT.csv")

# %%
stocks = pd.read_csv("stocksYT.csv", header=[0,1], index_col=[0], parse_dates=[0])

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2009-12-31    6.415357  19.068237   86.979034    7.526071  28.500000
# 2010-01-04    6.515212  19.081617   88.454178    7.643214  28.520000
# 2010-01-05    6.526476  18.850788   88.688332    7.656429  28.174999
# 2010-01-06    6.422665  18.844105   88.750771    7.534643  28.165001
# 2010-01-07    6.410790  18.797258   89.125435    7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.404587  50.318050  358.332703  131.970001  53.439999
# 2020-12-28  135.068604  50.995995  361.411041  136.690002  54.160000
# 2020-12-29  133.270172  50.967743  360.721527  134.869995  54.130001
# 2020-12-30  132.133850  51.259632  361.236206  133.720001  54.439999
# 2020-12-31  131.116058  51.636265  363.071594  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
# Convert Multi-Index to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2009-12-31           6.415357        19.068237         86.979034
# 2010-01-04           6.515212        19.081617         88.454178
# 2010-01-05           6.526476        18.850788         88.688332
# 2010-01-06           6.422665        18.844105         88.750771
# 2010-01-07           6.410790        18.797258         89.125435
# ...                       ...              ...               ...
# 2020-12-24         130.404587        50.318050        358.332703
# 2020-12-28         135.068604        50.995995        361.411041
# 2020-12-29         133.270172        50.967743        360.721527
# 2020-12-30         132.133850        51.259632        361.236206
# 2020-12-31         131.116058        51.636265        363.071594
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2009-12-31       7.526071    28.500000    111.440002      7.619643
# ...

# %%
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2009-12-31    6.415357  19.068237   86.979034    7.526071  28.500000
# 2010-01-04    6.515212  19.081617   88.454178    7.643214  28.520000
# 2010-01-05    6.526476  18.850788   88.688332    7.656429  28.174999
# 2010-01-06    6.422665  18.844105   88.750771    7.534643  28.165001
# 2010-01-07    6.410790  18.797258   89.125435    7.520714  28.094999
# ...                ...        ...         ...         ...        ...
# 2020-12-24  130.404587  50.318050  358.332703  131.970001  53.439999
# 2020-12-28  135.068604  50.995995  361.411041  136.690002  54.160000
# 2020-12-29  133.270172  50.967743  360.721527  134.869995  54.130001
# 2020-12-30  132.133850  51.259632  361.236206  133.720001  54.439999
# 2020-12-31  131.116058  51.636265  363.071594  132.690002  54.840000
#
# ...

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2770.000000  2770.000000  2770.000000  2770.000000  2770.000000
# mean     31.729843    33.219810   184.783997    33.768060    41.315493
# std      24.752585     8.444675    70.774616    24.573372     6.811654
# min       5.846675    16.890400    80.476753     6.858929    25.014999
# 25%      15.277409    27.438032   116.583973    17.471964    37.645000
# 50%      24.679909    32.764563   178.629341    26.985000    41.759998
# 75%      41.160246    38.813559   245.579159    42.996250    45.549999
# max     135.068604    54.743858   363.071594   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2770.000000  2770.000000  2770.000000  2770.000000  2770.000000
# ...

# %%
stocks.loc[:,'Close']
# Out:
#                   AAPL         KO         SPY
# Date
# 2009-12-31    7.526071  28.500000  111.440002
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2770 rows x 3 columns]

# %%
close = stocks.loc[:,'Close'].copy()

# %%
# Out:
#                   AAPL         KO         SPY
# Date
# 2009-12-31    7.526071  28.500000  111.440002
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2770 rows x 3 columns]

# %%
# %matplotlib inline
plt.style.use("seaborn")

# %%
close.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]
# Out:
# 7.526071071624756

# %%
close.AAPL
# Out:
# Date
# 2009-12-31      7.526071
# 2010-01-04      7.643214
# 2010-01-05      7.656429
# 2010-01-06      7.534643
# 2010-01-07      7.520714
#                  ...
# 2020-12-24    131.970001
# 2020-12-28    136.690002
# 2020-12-29    134.869995
# 2020-12-30    133.720001
# 2020-12-31    132.690002
# Name: AAPL, Length: 2770, dtype: float64

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)
# Out:
# Date
# 2009-12-31     100.000000
# 2010-01-04     101.556498
# 2010-01-05     101.732082
# 2010-01-06     100.113899
# 2010-01-07      99.928817
#                  ...
# 2020-12-24    1753.504584
# 2020-12-28    1816.219926
# 2020-12-29    1792.037224
# 2020-12-30    1776.757088
# 2020-12-31    1763.071345
# Name: AAPL, Length: 2770, dtype: float64

# %%
close.iloc[0]
# Out:
# AAPL      7.526071
# KO       28.500000
# SPY     111.440002
# Name: 2009-12-31 00:00:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8),fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl = close.AAPL.to_frame().copy()

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2009-12-31         NaN
# 2010-01-04    7.526071
# 2010-01-05    7.643214
# 2010-01-06    7.656429
# 2010-01-07    7.534643
# ...                ...
# 2020-12-24  130.960007
# 2020-12-28  131.970001
# 2020-12-29  136.690002
# 2020-12-30  134.869995
# 2020-12-31  133.720001
#
# [2770 rows x 1 columns]

# %%
aapl['lag1'] = aapl.shift(periods=1)

# %%
# Out:
#                   AAPL        lag1
# Date
# 2009-12-31    7.526071         NaN
# 2010-01-04    7.643214    7.526071
# 2010-01-05    7.656429    7.643214
# 2010-01-06    7.534643    7.656429
# 2010-01-07    7.520714    7.534643
# ...                ...         ...
# 2020-12-24  131.970001  130.960007
# 2020-12-28  136.690002  131.970001
# 2020-12-29  134.869995  136.690002
# 2020-12-30  133.720001  134.869995
# 2020-12-31  132.690002  133.720001
#
# [2770 rows x 2 columns]

# %%
aapl['Diff'] = aapl.AAPL.sub(aapl.lag1)

# %%
aapl["% Change"] = aapl.AAPL.div(aapl.lag1)

# %%
aapl["Diff2"] = aapl.AAPL.diff(aapl.lag1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# g:\My Drive\Projekter\QuantTradingStrats_Examples\Algorithmic_Trading_Tutorial\Main.ipynb Cell 33 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/g%3A/My%20Drive/Projekter/QuantTradingStrats_Examples/Algorithmic_Trading_Tutorial/Main.ipynb#X44sZmlsZQ%3D%3D?line=0'>1</a> aapl["Diff2"] = aapl.AAPL.diff(aapl.lag1)
#
# File c:\Projekter\py_venv\.venv\lib\site-packages\pandas\core\series.py:2697, in Series.diff(self, periods)
#    2612 @doc(
#    2613     klass="Series",
#    2614     extra_params="",
#    (...)
#    2660 )
#    2661 def diff(self, periods: int = 1) -> Series:
#    2662     """
#    2663     First discrete difference of element.
#    2664
#    (...)
#    2695     {examples}
#    2696     """
# -> 2697     result = algorithms.diff(self._values, periods)
# ...

# %%
aapl["% Change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl["% Change 2"] = aapl.AAPL.pct_change(periods=1).mul(100)

# %%
# Out:
#                   AAPL        lag1      Diff  % Change  % Change 2
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN         NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498    1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893    0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632   -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871   -0.184871
# ...                ...         ...       ...       ...         ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224    0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571    3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485   -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668   -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265   -0.770265
#
# [2770 rows x 5 columns]

# %%
del aapl["% Change 2"]

# %%
aapl
# Out:
#                   AAPL        lag1      Diff  % Change
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2770 rows x 4 columns]

# %%
aapl.rename(columns = {"% Change": "Change"}, inplace=True)

# %%
aapl
# Out:
#                   AAPL        lag1      Diff    Change
# Date
# 2009-12-31    7.526071         NaN       NaN       NaN
# 2010-01-04    7.643214    7.526071  0.117143  1.556498
# 2010-01-05    7.656429    7.643214  0.013215  0.172893
# 2010-01-06    7.534643    7.656429 -0.121786 -1.590632
# 2010-01-07    7.520714    7.534643 -0.013929 -0.184871
# ...                ...         ...       ...       ...
# 2020-12-24  131.970001  130.960007  1.009995  0.771224
# 2020-12-28  136.690002  131.970001  4.720001  3.576571
# 2020-12-29  134.869995  136.690002 -1.820007 -1.331485
# 2020-12-30  133.720001  134.869995 -1.149994 -0.852668
# 2020-12-31  132.690002  133.720001 -1.029999 -0.770265
#
# [2770 rows x 4 columns]

# %%
#Resample to monthly data 
#aapl.AAPL.resample("M").last()

# Resample to last business day of the month
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)
# Out:
# Date
# 2009-12-31          NaN
# 2010-01-29    -8.859672
# 2010-02-26     6.539620
# 2010-03-31    14.847028
# 2010-04-30    11.102138
#                 ...
# 2020-08-31    21.437974
# 2020-09-30   -10.252632
# 2020-10-30    -6.001206
# 2020-11-30     9.360649
# 2020-12-31    11.457370
# Freq: BM, Name: AAPL, Length: 133, dtype: float64

# %% [markdown]
# #### Expanding the list of tickers

# %%
tickers_new = ['SPY', 'AAPL', 'KO', 'IBM', 'MSFT', 'DIS']
stocks_new = yf.download(tickers_new, start='2010-01-01', end='2021-01-01')
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
close_new = stocks_new.loc[:,'Close']
# Out:
#                   AAPL         DIS         IBM         KO        MSFT  \
# Date
# 2009-12-31    7.526071   32.250000  125.143402  28.500000   30.480000
# 2010-01-04    7.643214   32.070000  126.625237  28.520000   30.950001
# 2010-01-05    7.656429   31.990000  125.095604  28.174999   30.959999
# 2010-01-06    7.534643   31.820000  124.282982  28.165001   30.770000
# 2010-01-07    7.520714   31.830000  123.852776  28.094999   30.450001
# ...                ...         ...         ...        ...         ...
# 2020-12-24  131.970001  173.729996  119.206497  53.439999  222.750000
# 2020-12-28  136.690002  178.860001  119.330788  54.160000  224.960007
# 2020-12-29  134.869995  177.300003  118.355644  54.130001  224.149994
# 2020-12-30  133.720001  181.169998  118.871895  54.439999  221.679993
# 2020-12-31  132.690002  181.179993  120.344170  54.840000  222.419998
#
#                    SPY
# Date
# 2009-12-31  111.440002
# 2010-01-04  113.330002
# 2010-01-05  113.629997
# ...

# %%
ret = close_new.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       DIS       IBM        KO      MSFT       SPY
# Date
# 2010-01-04  0.015565 -0.005581  0.011841  0.000702  0.015420  0.016960
# 2010-01-05  0.001729 -0.002495 -0.012080 -0.012097  0.000323  0.002647
# 2010-01-06 -0.015906 -0.005314 -0.006496 -0.000355 -0.006137  0.000704
# 2010-01-07 -0.001849  0.000314 -0.003462 -0.002485 -0.010400  0.004221
# 2010-01-08  0.006648  0.001571  0.010035 -0.018509  0.006897  0.003328

# %%
summary=ret.describe().T.loc[:,["mean", "std"]]
#summary
# Out:
#           mean       std
# AAPL  0.001196  0.017841
# DIS   0.000747  0.015715
# IBM   0.000086  0.014132
# KO    0.000298  0.011086
# MSFT  0.000846  0.016012
# SPY   0.000497  0.010911

# %%
summary["mean"] = summary["mean"]*252
summary['std'] = summary["std"]*np.sqrt(252)
#summary

# %%
summary.plot.scatter(x="std", y="mean", figsize=(12,8),s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,'std']+0.002, summary.loc[i, "mean"]+0.002), size=15)

plt.xlabel("Annual risk (std)", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/return", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/return')

# %% [markdown]
# #### Correlation and Covariance

# %%
# Covariance
ret.cov()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  0.000318  0.000114  0.000110  0.000067  0.000158  0.000128
# DIS   0.000114  0.000247  0.000111  0.000085  0.000121  0.000121
# IBM   0.000110  0.000111  0.000200  0.000079  0.000121  0.000108
# KO    0.000067  0.000085  0.000079  0.000123  0.000076  0.000077
# MSFT  0.000158  0.000121  0.000121  0.000076  0.000256  0.000130
# SPY   0.000128  0.000121  0.000108  0.000077  0.000130  0.000119

# %%
# Correlation 
ret.corr()
# Out:
#           AAPL       DIS       IBM        KO      MSFT       SPY
# AAPL  1.000000  0.408336  0.436236  0.339184  0.554168  0.659648
# DIS   0.408336  1.000000  0.497577  0.486494  0.480239  0.706195
# IBM   0.436236  0.497577  1.000000  0.502384  0.533257  0.703418
# KO    0.339184  0.486494  0.502384  1.000000  0.429696  0.639080
# MSFT  0.554168  0.480239  0.533257  0.429696  1.000000  0.744679
# SPY   0.659648  0.706195  0.703418  0.639080  0.744679  1.000000

# %%
import seaborn as sns
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Blues", annot=True, annot_kws={"size":15},vmax=0.6)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Simple returns and Log returns

# %%
df = pd.DataFrame(index=[2016, 2017, 2018], data=[100, 50, 84], columns=["Price"])

# %%
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     84

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017  -0.50
# 2018   0.68

# %%
# Mean returns are misleading as crazy
simplereturns.mean()
# Out:
# Price    0.09
# dtype: float64

# %%
logreturns = np.log(df/df.shift(1)).dropna()
logreturns
# Out:
#          Price
# 2017 -0.693147
# 2018  0.518794

# %%
# Mean of logreturns
logreturns.mean()
# Out:
# Price   -0.087177
# dtype: float64

# %%
# From logreturns back to price
100*np.exp(logreturns.mean()*2)
# Out:
# Price    84.0
# dtype: float64

# %% [markdown]
# #### Rolling windows on SPY data only

# %%
# Downloading only SPY data 
SPY = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy = SPY.Close.to_frame()

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)

# %%
spy_roll = spy.rolling(window=10)

# %%
# Calculating the mean
spy_roll = spy_roll.mean()

# %%
spy_roll.head(15)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.659375
# 1993-02-12  44.725000
# 1993-02-16  44.646875
# 1993-02-17  44.556250
# 1993-02-18  44.415625
# 1993-02-19  44.271875

# %%
# Calculatin the rolling median
spy_roll_med = spy.rolling(window=10).median()

# %%
spy_roll_med.head(30)
# Out:
#                 Close
# Date
# 1993-01-29        NaN
# 1993-02-01        NaN
# 1993-02-02        NaN
# 1993-02-03        NaN
# 1993-02-04        NaN
# 1993-02-05        NaN
# 1993-02-08        NaN
# 1993-02-09        NaN
# 1993-02-10        NaN
# 1993-02-11  44.765625
# 1993-02-12  44.765625
# 1993-02-16  44.765625
# 1993-02-17  44.765625
# 1993-02-18  44.687500
# 1993-02-19  44.625000
# 1993-02-22  44.156250
# 1993-02-23  43.703125
# 1993-02-24  43.703125
# 1993-02-25  43.703125
# 1993-02-26  43.703125
# 1993-03-01  43.703125
# 1993-03-02  43.984375
# 1993-03-03  44.265625
# 1993-03-04  44.312500
# 1993-03-05  44.375000
# 1993-03-08  44.578125
# 1993-03-09  44.812500
# 1993-03-10  44.906250
# 1993-03-11  45.031250
# 1993-03-12  45.109375

# %%
# Calculating the rolling max!
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-01-09  388.079987
# 2023-01-10  390.579987
# 2023-01-11  395.519989
# 2023-01-12  396.959991
# 2023-01-13  398.500000
#
# [7545 rows x 1 columns]

# %%
# Calculating the rolling max - setting the min_period = 5
spy_roll_min_per = spy.rolling(window=10, min_periods=5).max()
spy_roll_min_per.head(20)
# Out:
#                Close
# Date
# 1993-01-29       NaN
# 1993-02-01       NaN
# 1993-02-02       NaN
# 1993-02-03       NaN
# 1993-02-04  45.00000
# 1993-02-05  45.00000
# 1993-02-08  45.00000
# 1993-02-09  45.00000
# 1993-02-10  45.00000
# 1993-02-11  45.00000
# 1993-02-12  45.00000
# 1993-02-16  45.00000
# 1993-02-17  45.00000
# 1993-02-18  45.00000
# 1993-02-19  44.96875
# 1993-02-22  44.96875
# 1993-02-23  44.93750
# 1993-02-24  44.93750
# 1993-02-25  44.93750
# 1993-02-26  44.59375

# %%
#spy["SMA50"] = 
#spy.rolling(window=50, min_periods=50).mean()
#spy["SMA50"]
spy.head(52)
# Out:
#                Close     SMA50
# Date
# 1993-01-29  43.93750       NaN
# 1993-02-01  44.25000       NaN
# 1993-02-02  44.34375       NaN
# 1993-02-03  44.81250       NaN
# 1993-02-04  45.00000       NaN
# 1993-02-05  44.96875       NaN
# 1993-02-08  44.96875       NaN
# 1993-02-09  44.65625       NaN
# 1993-02-10  44.71875       NaN
# 1993-02-11  44.93750       NaN
# 1993-02-12  44.59375       NaN
# 1993-02-16  43.46875       NaN
# 1993-02-17  43.43750       NaN
# 1993-02-18  43.40625       NaN
# 1993-02-19  43.56250       NaN
# 1993-02-22  43.71875       NaN
# 1993-02-23  43.68750       NaN
# 1993-02-24  44.25000       NaN
# 1993-02-25  44.34375       NaN
# 1993-02-26  44.40625       NaN
# 1993-03-01  44.28125       NaN
# 1993-03-02  44.93750       NaN
# 1993-03-03  45.12500       NaN
# 1993-03-04  44.87500       NaN
# 1993-03-05  44.75000       NaN
# 1993-03-08  45.75000       NaN
# 1993-03-09  45.59375       NaN
# 1993-03-10  45.68750       NaN
# 1993-03-11  45.56250       NaN
# ...

# %%
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)

# %%
spy["SMA200"] = spy['Close'].rolling(window=200, min_periods=200).mean()
spy.plot(figsize=(12,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)

# %% [markdown]
# #### Calculate EWMA

# %%
spy["EMA100"] = spy.Close.ewm(span=100, min_periods=100).mean()

# %%
spy.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)

# %%
spy["Day"] = spy.index.day_name()

# %%
spy["Quarter"] = spy.index.quarter

# %%
spy
# Out:
#                  Close       SMA50      SMA200      EMA100        Day  Quarter
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday        1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday        1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday        1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday        1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday        1
# ...                ...         ...         ...         ...        ...      ...
# 2023-01-09  387.859985  389.729800  398.401601  390.020950     Monday        1
# 2023-01-10  390.579987  389.941799  398.102051  390.032020    Tuesday        1
# 2023-01-11  395.519989  390.071799  397.816201  390.140693  Wednesday        1
# 2023-01-12  396.959991  390.286799  397.521451  390.275728   Thursday        1
# 2023-01-13  398.500000  390.566400  397.206201  390.438585     Friday        1
#
# ...

# %% [markdown]
# #### RE-INDEXING

# %% [markdown]
# Start by reloading the SPY data into a new spy variable and from there do some reindezing manipulations!

# %%
SPY_2 = yf.download("SPY")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
all_days = pd.date_range(start="2010-12-31", end="2020-01-01", freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2019-12-23', '2019-12-24', '2019-12-25', '2019-12-26',
#                '2019-12-27', '2019-12-28', '2019-12-29', '2019-12-30',
#                '2019-12-31', '2020-01-01'],
#               dtype='datetime64[ns]', length=3289, freq='D')

# %%
SPY_2
spy_2=SPY_2.reindex(all_days)

# %%
spy_2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2010-12-31  125.529999  125.870003  125.330002  125.750000  100.074745
# 2011-01-01         NaN         NaN         NaN         NaN         NaN
# 2011-01-02         NaN         NaN         NaN         NaN         NaN
# 2011-01-03  126.709999  127.599998  125.699997  127.050003  101.109314
# 2011-01-04  127.330002  127.370003  126.190002  126.980003  101.053627
# ...                ...         ...         ...         ...         ...
# 2019-12-28         NaN         NaN         NaN         NaN         NaN
# 2019-12-29         NaN         NaN         NaN         NaN         NaN
# 2019-12-30  322.950012  323.100006  320.549988  321.079987  306.081909
# 2019-12-31  320.529999  322.130005  320.149994  321.859985  306.825531
# 2020-01-01         NaN         NaN         NaN         NaN         NaN
#
#                  Volume
# 2010-12-31   91218900.0
# 2011-01-01          NaN
# 2011-01-02          NaN
# ...

# %%
# The NaN's represents weekends and holidays! 
# We can use either forward-fill or backward-fill to resolve these

# Using forward-fill 
# spy_2.fillna(method="ffill")

# Using backward-fill 
spy_2.fillna(method="bfill")
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2010-12-31  125.529999  125.870003  125.330002  125.750000  100.074745
# 2011-01-01  126.709999  127.599998  125.699997  127.050003  101.109314
# 2011-01-02  126.709999  127.599998  125.699997  127.050003  101.109314
# 2011-01-03  126.709999  127.599998  125.699997  127.050003  101.109314
# 2011-01-04  127.330002  127.370003  126.190002  126.980003  101.053627
# ...                ...         ...         ...         ...         ...
# 2019-12-28  322.950012  323.100006  320.549988  321.079987  306.081909
# 2019-12-29  322.950012  323.100006  320.549988  321.079987  306.081909
# 2019-12-30  322.950012  323.100006  320.549988  321.079987  306.081909
# 2019-12-31  320.529999  322.130005  320.149994  321.859985  306.825531
# 2020-01-01         NaN         NaN         NaN         NaN         NaN
#
#                  Volume
# 2010-12-31   91218900.0
# 2011-01-01  138725200.0
# 2011-01-02  138725200.0
# ...

# %%
# Downloading data from YFinanc using weekly intervals
SPY = yf.download("SPY", interval="1wk")

# %% [markdown]
# #### Cumulative Returns, Drawdowns etc.

# %%
apple = yf.download("AAPL")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple = apple.Close.to_frame()

# %%
apple["Daily_returns"] = np.log(apple.div(apple.shift(1)))

# %%
apple
# Out:
#                  Close  Daily_returns
# Date
# 1980-12-12    0.128348            NaN
# 1980-12-15    0.121652      -0.053581
# 1980-12-16    0.112723      -0.076231
# 1980-12-17    0.115513       0.024450
# 1980-12-18    0.118862       0.028580
# ...                ...            ...
# 2023-01-10  130.729996       0.004447
# 2023-01-11  133.490005       0.020893
# 2023-01-12  133.410004      -0.000599
# 2023-01-13  134.759995       0.010068
# 2023-01-17  135.876907       0.008254
#
# [10613 rows x 2 columns]

# %%
apple.dropna(inplace=True)

# %%
apple
# Out:
#                  Close  Daily_returns
# Date
# 1980-12-15    0.121652      -0.053581
# 1980-12-16    0.112723      -0.076231
# 1980-12-17    0.115513       0.024450
# 1980-12-18    0.118862       0.028580
# 1980-12-19    0.126116       0.059239
# ...                ...            ...
# 2023-01-10  130.729996       0.004447
# 2023-01-11  133.490005       0.020893
# 2023-01-12  133.410004      -0.000599
# 2023-01-13  134.759995       0.010068
# 2023-01-17  135.876907       0.008254
#
# [10612 rows x 2 columns]

# %%
apple.Daily_returns.sum()
# Out:
# 6.964759392387049

# %%
np.exp(apple.Daily_returns.sum())
# Out:
# 1058.6601650844668

# %%
# Calculating column of cumulative return
apple["Cum. Return"] = apple.Daily_returns.cumsum().apply(np.exp)

# %%
apple
# Out:
#                  Close  Daily_returns  Cum. Return
# Date
# 1980-12-15    0.121652      -0.053581     0.947829
# 1980-12-16    0.112723      -0.076231     0.878261
# 1980-12-17    0.115513       0.024450     0.899998
# 1980-12-18    0.118862       0.028580     0.926092
# 1980-12-19    0.126116       0.059239     0.982610
# ...                ...            ...          ...
# 2023-01-10  130.729996       0.004447  1018.558941
# 2023-01-11  133.490005       0.020893  1040.063054
# 2023-01-12  133.410004      -0.000599  1039.439735
# 2023-01-13  134.759995       0.010068  1049.957942
# 2023-01-17  135.876907       0.008254  1058.660165
#
# [10612 rows x 3 columns]

# %%
apple["Cum. Return"].plot(figsize=(12,8), title="Apple buy and hold", fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Apple buy and hold'}, xlabel='Date'>

# %%
apple.Daily_returns.mean()*252
# Out:
# 0.16539006472686923

# %%
apple.Daily_returns.std()*np.sqrt(252)
# Out:
# 0.4556760595903013

# %%
# How to calculate drawdowns
# - we need to find the peak and the trough
apple["cummax"] = apple["Cum. Return"].cummax()

# %%
apple
# Out:
#                  Close  Daily_returns  Cum. Return       cummax
# Date
# 1980-12-15    0.121652      -0.053581     0.947829     0.947829
# 1980-12-16    0.112723      -0.076231     0.878261     0.947829
# 1980-12-17    0.115513       0.024450     0.899998     0.947829
# 1980-12-18    0.118862       0.028580     0.926092     0.947829
# 1980-12-19    0.126116       0.059239     0.982610     0.982610
# ...                ...            ...          ...          ...
# 2023-01-10  130.729996       0.004447  1018.558941  1418.097708
# 2023-01-11  133.490005       0.020893  1040.063054  1418.097708
# 2023-01-12  133.410004      -0.000599  1039.439735  1418.097708
# 2023-01-13  134.759995       0.010068  1049.957942  1418.097708
# 2023-01-17  135.876907       0.008254  1058.660165  1418.097708
#
# [10612 rows x 4 columns]

# %%
apple[["Cum. Return", "cummax"]].plot(figsize=(12,8), title="Apple buy and hold+cummax", fontsize=12)
# Out:
# <AxesSubplot:title={'center':'Apple buy and hold+cummax'}, xlabel='Date'>

# %%
apple["drawdown"] = apple["cummax"] - apple["Cum. Return"]

# %%
apple.drawdown.max()
# Out:
# 444.02718404402026

# %%
apple.drawdown.idxmax()
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
apple.loc[(apple.index<="2023-01-05")]
# Out:
#                  Close  Daily_returns  Cum. Return       cummax    drawdown
# Date
# 1980-12-15    0.121652      -0.053581     0.947829     0.947829    0.000000
# 1980-12-16    0.112723      -0.076231     0.878261     0.947829    0.069569
# 1980-12-17    0.115513       0.024450     0.899998     0.947829    0.047831
# 1980-12-18    0.118862       0.028580     0.926092     0.947829    0.021738
# 1980-12-19    0.126116       0.059239     0.982610     0.982610    0.000000
# ...                ...            ...          ...          ...         ...
# 2022-12-29  129.610001       0.027931  1009.832703  1418.097708  408.265004
# 2022-12-30  129.929993       0.002466  1012.325863  1418.097708  405.771845
# 2023-01-03  125.070000      -0.038122   974.460113  1418.097708  443.637594
# 2023-01-04  126.360001       0.010261   984.510920  1418.097708  433.586787
# 2023-01-05  125.019997      -0.010661   974.070524  1418.097708  444.027184
#
# [10605 rows x 5 columns]

# %%
apple["drawdown%"] = (apple["cummax"]-apple["Cum. Return"])/apple["cummax"]

# %%
apple["drawdown%"].max()
# Out:
# 0.82216567924191

# %%
apple["drawdown%"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
apple.loc[(apple.index<='1997-12-23')]
# Out:
#                Close  Daily_returns  Cum. Return    cummax  drawdown  \
# Date
# 1980-12-15  0.121652      -0.053581     0.947829  0.947829  0.000000
# 1980-12-16  0.112723      -0.076231     0.878261  0.947829  0.069569
# 1980-12-17  0.115513       0.024450     0.899998  0.947829  0.047831
# 1980-12-18  0.118862       0.028580     0.926092  0.947829  0.021738
# 1980-12-19  0.126116       0.059239     0.982610  0.982610  0.000000
# ...              ...            ...          ...       ...       ...
# 1997-12-17  0.124442      -0.026549     0.969567  5.060882  4.091315
# 1997-12-18  0.123326      -0.009008     0.960872  5.060882  4.100010
# 1997-12-19  0.122210      -0.009090     0.952177  5.060882  4.108705
# 1997-12-22  0.118862      -0.027778     0.926092  5.060882  4.134790
# 1997-12-23  0.115513      -0.028580     0.899998  5.060882  4.160883
#
#             drawdown%
# Date
# 1980-12-15   0.000000
# 1980-12-16   0.073398
# 1980-12-17   0.050464
# 1980-12-18   0.022934
# ...

# %% [markdown]
# #### SMA Strategy

# %%
data = apple.Close.loc[(apple.index>='1991-01-01')]

# %%
data=data.to_frame()

# %%
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-01-10  130.729996
# 2023-01-11  133.490005
# 2023-01-12  133.410004
# 2023-01-13  134.759995
# 2023-01-17  135.876907
#
# [8072 rows x 1 columns]

# %%
sma_s=50
sma_l=100

# %%
data["sma_s"]=data.Close.rolling(sma_s).mean()
data["sma_l"]=data.Close.rolling(sma_l).mean()

# %%
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-01-02    0.388393         NaN         NaN
# 1991-01-03    0.383929         NaN         NaN
# 1991-01-04    0.386161         NaN         NaN
# 1991-01-07    0.386161         NaN         NaN
# 1991-01-08    0.386161         NaN         NaN
# ...                ...         ...         ...
# 2023-01-10  130.729996  140.682999  146.425699
# 2023-01-11  133.490005  140.237999  146.019099
# 2023-01-12  133.410004  139.839399  145.637999
# 2023-01-13  134.759995  139.521599  145.309899
# 2023-01-17  135.876907  139.338537  144.996368
#
# [8072 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title="AAPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize=12)
# Out:
# <AxesSubplot:title={'center':'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.loc["2016"].plot(figsize=(12,8), title="AAPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize=12)
# Out:
# <AxesSubplot:title={'center':'AAPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close       sma_s       sma_l
# Date
# 1991-05-23    0.402902    0.534420    0.513326
# 1991-05-24    0.409598    0.530960    0.513538
# 1991-05-28    0.410714    0.527344    0.513806
# 1991-05-29    0.419643    0.523638    0.514141
# 1991-05-30    0.425223    0.519732    0.514531
# ...                ...         ...         ...
# 2023-01-10  130.729996  140.682999  146.425699
# 2023-01-11  133.490005  140.237999  146.019099
# 2023-01-12  133.410004  139.839399  145.637999
# 2023-01-13  134.759995  139.521599  145.309899
# 2023-01-17  135.876907  139.338537  144.996368
#
# [7973 rows x 3 columns]

# %%
data["position"] = np.where(data["sma_s"]>data["sma_l"],1,-1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1    0.016483  0.016483
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209 -0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-01-10  130.729996  140.682999  146.425699        -1    0.004447 -0.004447
# 2023-01-11  133.490005  140.237999  146.019099        -1    0.020893 -0.020893
# 2023-01-12  133.410004  139.839399  145.637999        -1   -0.000599  0.000599
# 2023-01-13  134.759995  139.521599  145.309899        -1    0.010068 -0.010068
# 2023-01-17  135.876907  139.338537  144.996368        -1    0.008254 -0.008254
#
# ...

# %%
data.loc["2016",["sma_s","sma_l", "position"]].plot(figsize=(12,8), title="APPLE - SMA{} | SMA{}".format(sma_s, sma_l), fontsize=12, secondary_y="position")
# Out:
# <AxesSubplot:title={'center':'APPLE - SMA50 | SMA100'}, xlabel='Date'>

# %%
data["returnsb&h"] = np.log(data.Close.div(data.Close.shift(1)))

# %%
data["strategy"]=data["returnsb&h"]*data.position.shift(1)

# %%
data
# Out:
#                  Close       sma_s       sma_l  position  returnsb&h  strategy
# Date
# 1991-05-24    0.409598    0.530960    0.513538         1         NaN       NaN
# 1991-05-28    0.410714    0.527344    0.513806         1    0.002721  0.002721
# 1991-05-29    0.419643    0.523638    0.514141         1    0.021507  0.021507
# 1991-05-30    0.425223    0.519732    0.514531         1    0.013209  0.013209
# 1991-05-31    0.419643    0.516027    0.514866         1   -0.013209 -0.013209
# ...                ...         ...         ...       ...         ...       ...
# 2023-01-10  130.729996  140.682999  146.425699        -1    0.004447 -0.004447
# 2023-01-11  133.490005  140.237999  146.019099        -1    0.020893 -0.020893
# 2023-01-12  133.410004  139.839399  145.637999        -1   -0.000599  0.000599
# 2023-01-13  134.759995  139.521599  145.309899        -1    0.010068 -0.010068
# 2023-01-17  135.876907  139.338537  144.996368        -1    0.008254 -0.008254
#
# ...

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy"]].sum()
# Out:
# returnsb&h    5.804328
# strategy      2.046598
# dtype: float64

# %%
# What 1$ investment will become
data[["returnsb&h", "strategy"]].sum().apply(np.exp)
# Out:
# returnsb&h    331.732356
# strategy        7.741518
# dtype: float64

# %%
# Annual standard deviation 
data[["returnsb&h", "strategy"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.440112
# strategy      0.440245
# dtype: float64

# %% [markdown]
# ### Strategy adjusted with Long Bias

# %%
data['position2']=np.where(data["sma_s"]>data["sma_l"],1,0)
data['strategy2'] = data["returnsb&h"]*data.position2.shift(1)

# %%
data.dropna(inplace=True)

# %%
data[["returnsb&h", "strategy2"]].sum()
# Out:
# returnsb&h    5.801608
# strategy2     3.922742
# dtype: float64

# %%
# What 1$ investment will become
data[["returnsb&h", "strategy2"]].sum().apply(np.exp)
# Out:
# returnsb&h    330.830961
# strategy2      50.538842
# dtype: float64

# %%
# Annual standard deviation 
data[["returnsb&h", "strategy2"]].std()*np.sqrt(252)
# Out:
# returnsb&h    0.440140
# strategy2     0.340211
# dtype: float64

# %%
## Strategy 2 performs better than strategy 1 
data[["strategy", "strategy2"]].std()*np.sqrt(252)
# Out:
# strategy     0.440273
# strategy2    0.340211
# dtype: float64

# %% [markdown]
# #### Creating Functions

# %%
def test_strategy(stock, start,end, SMA):
    df = yf.download(stock, start=start, end=end)
    data=df.Close.to_frame()
    data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"] = data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"] = data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    data["position"] = np.where(data["SMA_S"]>data["SMA_L"],1,-1)
    data["strategy"] = data["returns"]*data.position.shift(1)
    data.dropna(inplace=True)
    ret = np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)

    return ret, std

# %%
test_strategy("MSFT", "2000-01-01", "2020-01-01", (50,200))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (0.417174208955019, 0.2910259091645695)

# %% [markdown]
# #### Creating our first Class

# %%
class SMABacktester():
    def __init__(self, symbol, SMA_S, SMA_L, start,end) -> None:
        self.symbol = symbol 
        self.SMA_S = SMA_S
        self.SMA_L = SMA_L
        self.start = start 
        self.end = end 
        self.result = None 
        self.get_data()

    def get_data(self):
        df = yf.download(self.symbol, start=self.start, end=self.end)
        data=df.Close.to_frame()
        data["returns"] = np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"] = data.Close.rolling(self.SMA_S).mean()
        data["SMA_L"] = data.Close.rolling(self.SMA_L).mean()
        data.dropna(inplace=True)
        self.data2 = data 

        return data 

    def test_results(self):
        data = self.data2.copy().dropna()
        data['position'] = np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["strategy"] = data["returns"]*data.position.shift(1)
        data.dropna(inplace=True)
        data["returnsbh"] = data["returns"].cumsum().apply(np.exp)
        data["returnsstrategy"] = data["strategy"].cumsum().apply(np.exp)
        perf = data["returnsstrategy"].iloc[-1]
        outperf = perf-data["returnsbh"].iloc[-1]
        self.result = data 

        ret = np.exp(data["strategy"]).sum()
        std = data["strategy"].std()*np.sqrt(252)

        return round(perf, 6), round(outperf, 6)

    def plot_results(self):
        if self.result is None: 
            print("Run the test please!")
        else: 
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.result[["returnsbh", "returnsstrategy"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester("FORD", 50, 200, "2010-01-01", "2022-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()
# Out:
# (2.030628, 1.633682)

# %%
tester.plot_results()

# %% [markdown]
# ## API
# ###
